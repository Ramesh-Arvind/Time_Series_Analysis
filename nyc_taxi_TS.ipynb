# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramesh-Arvind/Time_Series_Analysis/blob/master/nyc_taxi_TS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyod
# !pip install holoviews
# !pip install statsmodels
# !pip install pmdarima
# !pip install pycaret
# !pip install prophet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import warnings
import seaborn as sns
from pandas.plotting import lag_plot
import scipy.stats as stats
from joblib import dump, load
warnings.filterwarnings('ignore')
from statsmodels.graphics.gofplots import qqplot
from pyod.utils.utility import standardizer
import holoviews as hv
from holoviews import opts
from bokeh.plotting import show
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.stats.diagnostic import kstest_normal
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from pyod.models.iforest import IForest
from pyod.models.ocsvm import OCSVM
from pyod.models.copod import COPOD
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.tsa.api as smt
import pmdarima as pm
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
from pyod.utils.utility import standardizer
hv.extension('bokeh')
from pycaret.anomaly import *
from prophet import Prophet
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
plt.rcParams["figure.figsize"] = [16, 3]

path = Path('/content/nyc_taxi.csv')

nyc_df = pd.read_csv(path.joinpath('nyc_taxi.csv'), index_col='timestamp', parse_dates=True)
nyc_df.index.freq = '30T'

print(nyc_df.head(5))
# Out:
#                      value
# timestamp
# 2014-07-01 00:00:00  10844
# 2014-07-01 00:30:00   8127
# 2014-07-01 01:00:00   6210
# 2014-07-01 01:30:00   4656
# 2014-07-01 02:00:00   3820

# %% [markdown]
# Checking for blank values and data types

# %%
def blank_data_check(df: pd.DataFrame, timestamp_col: str = None) -> None:
    print('Null count:\n', df.isnull().sum(), '\n')
    print('Data Type:\n', df.dtypes, '\n')

    if timestamp_col is not None:
        if timestamp_col in df.index.names:
            timestamp_series = df.index.get_level_values(timestamp_col)
            print('Date Range:\nStart:\t', timestamp_series.min())
            print('End:\t', timestamp_series.max())
            print('Days:\n', timestamp_series.max() - timestamp_series.min())
        else:
            print(f"'{timestamp_col}' index not found in DataFrame.")


print(blank_data_check(nyc_df, timestamp_col='timestamp'))
# Out:
# Null count:
#  value    0
# dtype: int64
#
# Data Type:
#  value    int64
# dtype: object
#
# Date Range:
# Start:	 2014-07-01 00:00:00
# End:	 2015-01-31 23:30:00
# Days:
#  214 days 23:30:00
# None

# %% [markdown]
# Resampling based on daily, hourly, weekly

# %%
Hourly = hv.Curve(nyc_df.resample('H').mean()).opts(
    opts.Curve(title="New York City Taxi Demand Hourly", xlabel="", ylabel="Demand",
               width=700, height=300, tools=['hover'], show_grid=True))

Weekly = hv.Curve(nyc_df.resample('W').mean()).opts(
    opts.Curve(title="New York City Taxi Demand Weekly", xlabel="", ylabel="Demand",
               width=700, height=300, tools=['hover'], show_grid=True))

Daily = hv.Curve(nyc_df.resample('D').mean()).opts(
    opts.Curve(title="New York City Taxi Demand Daily", xlabel="", ylabel="Demand",
               width=700, height=300, tools=['hover'], show_grid=True))

combined_holo = (Hourly + Daily + Weekly).opts(shared_axes=False).cols(1)
show(hv.render(combined_holo))
# Out:
#   <div id="dbe82026-c390-4d5e-abe3-96e290edc837" data-root-id="p1186" style="display: contents;"></div>

# %% [markdown]
# Distribute the plot for hourly, weekly, daily

# %%
df_hourly = nyc_df.resample('H').mean().reset_index()
df_daily = nyc_df.resample('D').mean().reset_index()
df_weekly = nyc_df.resample('W').mean().reset_index()

for DataFrame in [df_hourly, df_daily]:
    DataFrame['Weekday'] = pd.Categorical(DataFrame['timestamp'].dt.strftime('%A'),
                                          categories=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
                                                      'Saturday', 'Sunday'])
    DataFrame['Hour'] = DataFrame['timestamp'].dt.hour
    DataFrame['Day'] = DataFrame['timestamp'].dt.weekday
    DataFrame['Month'] = DataFrame['timestamp'].dt.month
    DataFrame['Year'] = DataFrame['timestamp'].dt.year
    DataFrame['Month_day'] = DataFrame['timestamp'].dt.day
    DataFrame['Lag'] = DataFrame['value'].shift(1)
    DataFrame['Rolling_Mean'] = DataFrame['value'].rolling(7).mean()

value_plot = (hv.Distribution(nyc_df['value'])
              .opts(opts.Distribution(title="Overall Value Distribution",
                                      xlabel="Value",
                                      ylabel="Density",
                                      width=700, height=300,
                                      tools=['hover'], show_grid=True)
                    ))
show(hv.render(value_plot))
# Out:
#   <div id="d91c977d-3b1a-47fe-aa6b-69e96ffdca39" data-root-id="p1208" style="display: contents;"></div>

# %%
by_weekday = df_hourly.groupby(['Hour', 'Weekday']).mean()['value'].unstack()
by_weekday_plot = (hv.Distribution(by_weekday['Monday'], label='Monday')
                   * hv.Distribution(by_weekday['Tuesday'], label='Tuesday')
                   * hv.Distribution(by_weekday['Wednesday'], label='Wednesday')
                   * hv.Distribution(by_weekday['Thursday'], label='Thursday')
                   * hv.Distribution(by_weekday['Friday'], label='Friday')
                   * hv.Distribution(by_weekday['Saturday'], label='Saturday')
                   * hv.Distribution(by_weekday['Sunday'], label='Sunday')
                   .opts(opts.Distribution(title="Value Density by Day & Hour")))
by_weekday_plot.opts(
    opts.Distribution(width=800, height=300, tools=['hover'], show_grid=True, ylabel="Value", xlabel="Value"))

show(hv.render(by_weekday_plot))
# Out:
#   <div id="ea123ece-a938-4feb-b8f4-7da0f0bb361b" data-root-id="p1275" style="display: contents;"></div>

# %% [markdown]
# Demand by weekly

# %%
daily_plot = hv.Bars(df_hourly[['value', 'Weekday']].groupby('Weekday').mean()).opts(
    opts.Bars(title="New York City Taxi Demand by Day", xlabel="", ylabel="Demand",
              width=700, height=300, tools=['hover'], show_grid=True))
show(hv.render(daily_plot))
# Out:
#   <div id="cda86a5f-dd06-498d-8be7-e42a6239028b" data-root-id="p1422" style="display: contents;"></div>

# %% [markdown]
# Demand by hourly

# %%
hourly_plot = hv.Curve(df_hourly[['value', 'Hour']].groupby('Hour').mean()).opts(
    opts.Curve(title='New York City Demand By Hour', xlabel="Hour", ylabel="Demand",
               width=700, height=300, tools=['hover'], show_grid=True))

show(hv.render(hourly_plot))
# Out:
#   <div id="f1bbb6f6-d26b-48f2-aa29-1996b61f693f" data-root-id="p1470" style="display: contents;"></div>

# %% [markdown]
# Demand by Day and Hour

# %%
by_day_hour = df_hourly.groupby(['Hour', 'Weekday']).mean()['value'].unstack()
by_day_hour_plot = (hv.Curve(by_day_hour['Monday'], label='Monday')
                    * hv.Curve(by_day_hour['Tuesday'], label='Tuesday')
                    * hv.Curve(by_day_hour['Wednesday'], label='Wednesday')
                    * hv.Curve(by_day_hour['Thursday'], label='Thursday')
                    * hv.Curve(by_day_hour['Friday'], label='Friday')
                    * hv.Curve(by_day_hour['Saturday'], label='Saturday')
                    * hv.Curve(by_day_hour['Sunday'], label='Sunday')
                    .opts(opts.Curve(title="Value Density by Day & Hour")))
by_day_hour_plot.opts(
    opts.Curve(width=800, height=300, tools=['hover'], show_grid=True, ylabel="Demand", xlabel="Value"))

show(hv.render(by_day_hour_plot))
# Out:
#   <div id="fc25ae22-0b17-4b4b-9438-b404c24e911c" data-root-id="p1537" style="display: contents;"></div>

# %%
df_hourly = (df_hourly
             .join(df_hourly.groupby(['Hour', 'Weekday'])['value'].mean(),
                   on=['Hour', 'Weekday'], rsuffix='_Average')
             )

df_daily = (df_daily
            .join(df_daily.groupby(['Hour', 'Weekday'])['value'].mean(),
                  on=['Hour', 'Weekday'], rsuffix='_Average')
            )

print(df_hourly.tail())
# Out:
#                timestamp    value   Weekday  Hour  Day  Month  Year  \
# 5155 2015-01-31 19:00:00  28288.5  Saturday    19    5      1  2015
# 5156 2015-01-31 20:00:00  24138.0  Saturday    20    5      1  2015
# 5157 2015-01-31 21:00:00  24194.5  Saturday    21    5      1  2015
# 5158 2015-01-31 22:00:00  26515.0  Saturday    22    5      1  2015
# 5159 2015-01-31 23:00:00  26439.5  Saturday    23    5      1  2015
#
#       Month_day      Lag  Rolling_Mean  value_Average
# 5155         31  26665.0  23537.214286   24501.870968
# 5156         31  28288.5  23673.571429   22193.758065
# 5157         31  24138.0  24031.214286   21983.241935
# 5158         31  24194.5  24635.714286   23949.951613
# 5159         31  26515.0  25485.071429   25192.516129

# %% [markdown]
# Interpolate the data

# %%
df_hourly_nan = df_hourly.dropna(inplace=True)

model_data = df_hourly[['value', 'Hour', 'Day', 'Month_day', 'Month', 'Rolling_Mean', 'Lag', 'timestamp']].set_index(
    'timestamp').dropna()
model_data.interpolate(method='linear', inplace=True)
print(model_data.head())

model_data.index = pd.to_datetime(model_data.index)

# Interpolate time series
plt.figure(figsize=(12, 6))
plt.plot(model_data.index, model_data['value'], label='Interpolated Data', color='grey')
plt.title('Interpolated Time Series Data')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#                        value  Hour  Day  Month_day  Month  Rolling_Mean  \
# timestamp
# 2014-07-01 06:00:00   8782.5     6    1          1      7   4984.714286
# 2014-07-01 07:00:00  14861.0     7    1          1      7   5752.642857
# 2014-07-01 08:00:00  19133.0     8    1          1      7   7709.785714
# 2014-07-01 09:00:00  19823.0     9    1          1      7  10063.571429
# 2014-07-01 10:00:00  18352.0    10    1          1      7  12368.642857
#
#                          Lag
# timestamp
# 2014-07-01 06:00:00   3439.5
# 2014-07-01 07:00:00   8782.5
# 2014-07-01 08:00:00  14861.0
# 2014-07-01 09:00:00  19133.0
# 2014-07-01 10:00:00  19823.0

# %% [markdown]
# Seasonal Decompose

# %%
decomposition = seasonal_decompose(model_data['value'], model='additive', period=24)

plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(model_data.index, decomposition.trend, label='Trend', color='blue')
plt.title('Seasonal Decomposition')
plt.xlabel('Timestamp')
plt.ylabel('Trend')
plt.legend()
plt.grid(True)

plt.subplot(412)
plt.plot(model_data.index, decomposition.seasonal, label='Seasonal', color='green')
plt.xlabel('Timestamp')
plt.ylabel('Seasonal')
plt.legend()
plt.grid(True)

plt.subplot(413)
plt.plot(model_data.index, decomposition.resid, label='Residual', color='red')
plt.xlabel('Timestamp')
plt.ylabel('Residual')
plt.legend()
plt.grid(True)

plt.subplot(414)
plt.plot(model_data.index, model_data['value'], label='Original Data', color='black')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Check for stationary

# %%
def print_results(output, test='adf'):
    pval = output[1]
    test_score = output[0]
    lags = output[2]
    decision = 'Non-Stationary'
    if test == 'adf':
        critical = output[4]
        if pval < 0.05:
            decision = 'Stationary'
    elif test == 'kpss':
        critical = output[3]
        if pval >= 0.05:
            decision = 'Stationary'
    output_dict = {
        'Test Statistic': test_score,
        'p-value': pval,
        'Numbers of lags': lags,
        'decision': decision
    }
    for key, value in critical.items():
        output_dict["Critical Value (%s)" % key] = value

    return pd.Series(output_dict, name=test)


nyc_stationary_adf = adfuller(nyc_df)
nyc_stationary_kpss = kpss(nyc_df)

nyc_stationary_comparison = pd.concat([
    print_results(nyc_stationary_adf, 'adf'),
    print_results(nyc_stationary_kpss, 'kpss')
], axis=1)

print(nyc_stationary_comparison)
# Out:
#                               adf        kpss
# Test Statistic         -10.764517    0.418064
# p-value                       0.0    0.069369
# Numbers of lags                39          52
# decision               Stationary  Stationary
# Critical Value (1%)     -3.430986       0.739
# Critical Value (5%)     -2.861821       0.463
# Critical Value (10%)     -2.56692       0.347
# Critical Value (2.5%)         NaN       0.574

# %% [markdown]
# Based on the investigation we have some dates where we will get outliers becasue of festval dates are included.
# # We should consider this dates as of now as labelled dates as outliers
#
# 1. Saturday, November 1, 2014, was before the New York Marathon, and the official marathon event was on Sunday, November 2, 2014.
# 2. Thursday, November 27, 2014, was Thanksgiving Day.
# 3. Thursday, December 25, 2014, was Christmas Day.
# 4. Thursday, January 1, 2015, was New Year's Day.
# 5. Tuesday, January 27, 2015, was the North American Blizzard where all vehicles were ordered off the street from January 26 to January 27, 2015.

# %%
nyc_dates = [
    "2014-11-01",
    "2014-11-27",
    "2014-12-25",
    "2015-01-01",
    "2015-01-27"
]


# Plot the outliers
def plot_outliers(outliers, data, method='KNN',
                  halignment='right',
                  valignment='bottom',
                  labels=False):
    ax = data.plot(alpha=0.6)

    if labels:
        for i in outliers['value'].items():
            plt.plot(i[0], i[1], 'rx')
            plt.text(i[0], i[1], f'{i[0].date()}',
                     horizontalalignment=halignment,
                     verticalalignment=valignment)
    else:
        data.loc[outliers.index].plot(ax=ax, style='rx')

    plt.title(f'NYC Taxi - {method}')
    plt.xlabel('date')
    plt.ylabel('# of passengers')
    plt.legend(['nyc taxi', 'outliers'])
    plt.show()

# %% [markdown]
# Monthly aggregation data observation

# %%
nyc_taxi_monthly = nyc_df.resample('MS').agg(['mean', 'min',
                                              'max', 'median', 'sum'])
print(nyc_taxi_monthly)

# Dataset has 10,280 record we will change data to daily frequency using resampling
daily_nyc_taxi = nyc_df.resample('D').mean()
known_outliers = daily_nyc_taxi.loc[nyc_dates]
plot_outliers(known_outliers, daily_nyc_taxi, 'Known_outliers')
plt.show()

# Different plot for outloer detection and statistical test, plotting with different charts to identify the outliers and understand better
sns.histplot(daily_nyc_taxi)
plt.show()
# Out:
#                    value
#                     mean   min    max   median       sum
# timestamp
# 2014-07-01  14994.084677  1769  29985  16625.5  22311198
# 2014-08-01  14580.438844  1841  26062  16184.0  21695693
# 2014-09-01  15623.374306  1431  30373  17244.5  22497659
# 2014-10-01  16086.851478  1691  28626  17767.5  23937235
# 2014-11-01  15492.125000  1683  39197  17287.0  22308660
# 2014-12-01  14813.428763  1459  27804  16587.0  22042382
# 2015-01-01  14399.790995     8  30236  16061.0  21426889

# %% [markdown]
# Non parametric statistical test using IQR from Q1 to Q3
#
# 1.   Lower fence is calculated by Q1-(1.5*IQR)
# 2.   Upper fence is calculated by Q3+(1.5*IQR)
# 3.   The difference between the Q3 and Q1 is median

# %%
def iqr_outliers(data):
    q1, q3 = np.percentile(data, [25, 75])
    IQR = q3 - q1
    lower_fence = q1 - (1.5 * IQR)
    upper_fence = q3 + (1.5 * IQR)
    return data[(data.value > upper_fence) | (data.value < lower_fence)]


iqr = iqr_outliers(daily_nyc_taxi)
plt.show()

sns.boxplot(daily_nyc_taxi['value'], whis=1.5)
plt.show()

# %% [markdown]
# As we have the numerical value will show a different methods such as tukey, proportion, trustworthy, or full as referenced paper by Heike Hofmann, Hadley Wickham & Karen Kafadar (2017)

# %%
for k in ["tukey", "proportion", "trustworthy", "full"]:
    sns.boxenplot(daily_nyc_taxi['value'], k_depth=k)
    plt.title(k)
    plt.show()

# %% [markdown]
# We will use the kernel density estimatation. We use this to identify the
# large probablity function that estimate the peaks where the major points are observed.

# %%
sns.violinplot(daily_nyc_taxi['value'], inner='quartile')
plt.show()

# %% [markdown]
# Lag plot used to identify the corelation between two variables but in this datast we will identify the same plot with lagged version

# %%
lag_plot(daily_nyc_taxi)
plt.show()

# %% [markdown]
# # Descriptive Statistics:

# %%
percentiles = [0, 0.05, .10, .25, .5, .75, .90, .95, 1]
print(daily_nyc_taxi.describe(percentiles=percentiles))
# Out:
#               value
# count    215.000000
# mean   15137.569380
# std     1937.391020
# min     4834.541667
# 0%      4834.541667
# 5%     11998.181250
# 10%    13043.854167
# 25%    14205.197917
# 50%    15299.937500
# 75%    16209.427083
# 90%    17279.300000
# 95%    18321.616667
# 100%   20553.500000
# max    20553.500000

# %% [markdown]
# # Standardize Data

# %%
def zscore(df, degree=3):
    data = df.copy()
    data['zscore'] = (data - data.mean()) / data.std()
    outliers = data[(data['zscore'] <= -degree) |
                    (data['zscore'] >= degree)]

    return outliers['value'], data


threshold = 2.5
outliers, transformed = zscore(daily_nyc_taxi, threshold)

transformed.hist()
plt.show()
print(outliers)
# Out:
# timestamp
# 2014-11-01    20553.500000
# 2014-12-25     7902.125000
# 2015-01-26     7818.979167
# 2015-01-27     4834.541667
# Name: value, dtype: float64

# %% [markdown]
# # Normal Distribution

# %%
def test_normal(df):
    t_test, p_value = kstest_normal(df)
    if p_value < 0.05:
        print("Reject null hypothesis. Data is not normal")
    else:
        print("Fail to reject null hypothesis. Data is normal")


test_normal(daily_nyc_taxi)
# Out:
# Reject null hypothesis. Data is not normal

# %% [markdown]
# Null hypothesis is rejected because data is not normally distributed
# If the data is not normal we can use the other approach modified z score
# Instead of using mean and standard deviation in z score we can use median and mean absolute deviation

# %%
def modified_zscore(df, degree=3):
    data = df.copy()
    s = stats.norm.ppf(0.75)
    numerator = s * (data - data.median())
    MAD = np.abs(data - data.median()).median()
    data['m_zscore'] = numerator / MAD
    outliers = data[(data['m_zscore'] > degree) |
                    (data['m_zscore'] < -degree)]

    return outliers['value'], data


threshold = 3
outlier, transformed_md = modified_zscore(daily_nyc_taxi, threshold)

transformed_md.hist()
plt.show()
print(outlier)

plot_outliers(outlier, daily_nyc_taxi, "Outliers using modified z score")
plt.show()
# Out:
# timestamp
# 2014-11-01    20553.500000
# 2014-11-27    10899.666667
# 2014-12-25     7902.125000
# 2014-12-26    10397.958333
# 2015-01-26     7818.979167
# 2015-01-27     4834.541667
# Name: value, dtype: float64

# %%
# QQ plot
qqplot(daily_nyc_taxi.values.reshape(-1), line='s')
plt.show()

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # pyod using knn:
#
# We identified already five outliers in the datast, so the contamination value influences the threshold value to identify the potential outliers

# %%
knn = KNN(contamination=0.03, method='mean', n_neighbors=5)
knn.fit(daily_nyc_taxi)

predicted_knn = pd.Series(knn.predict(daily_nyc_taxi), index=daily_nyc_taxi.index)
print('Number of outliers',predicted_knn.sum())

outlier_knn = predicted_knn[predicted_knn == 1]
outlier_knn = daily_nyc_taxi.loc[outlier_knn.index]
print(outlier_knn)

plot_outliers(outlier_knn,daily_nyc_taxi,'KNN',labels=True)
# Out:
# Number of outliers 6
#                    value
# timestamp
# 2014-11-01  20553.500000
# 2014-11-27  10899.666667
# 2014-12-25   7902.125000
# 2014-12-26  10397.958333
# 2015-01-26   7818.979167
# 2015-01-27   4834.541667

# %%
knn_scores = knn.decision_scores_
knn_scores_df = (pd.DataFrame(knn_scores,
                              index=daily_nyc_taxi.index,
                              columns=['score']))

knn_scores_df[knn_scores_df['score'] >= knn.threshold_].sort_values('score', ascending=False)
# Out:
#                   score
# timestamp
# 2015-01-27  4862.058333
# 2015-01-26  2474.508333
# 2014-12-25  2441.250000
# 2014-11-01  1806.850000
# 2014-12-26  1009.616667
# 2014-11-27   608.250000
# 2014-09-27   225.604167

# %%
n = int(len(daily_nyc_taxi) * 0.03)
knn_scores_df.nlargest(n, 'score')
print(knn_scores_df.min())

knn_proba = knn.predict_proba(daily_nyc_taxi, method='linear')
knn_proba_df = (pd.DataFrame(np.round(knn_proba * 100, 3),
                             index=daily_nyc_taxi.index,
                             columns=['Proba_Normal', 'Proba_Anomaly']))
knn_proba_df.nlargest(n, 'Proba_Anomaly')
# Out:
# score    11.745833
# dtype: float64
#             Proba_Normal  Proba_Anomaly
# timestamp
# 2015-01-27        27.337         72.663
# 2015-01-26        64.256         35.744
# 2014-12-25        64.599         35.401
# 2014-11-01        70.682         29.318
# 2014-12-26        84.341         15.659
# 2014-11-27        90.548          9.452

# %%
# save the model
dump(knn, 'knn_outliers.joblib')
# load the model
knn = load('knn_outliers.joblib')

# %%
scaled = standardizer(daily_nyc_taxi)
predicted = pd.Series(knn.fit_predict(scaled),
                      index=daily_nyc_taxi.index)
outliers_scaled = predicted[predicted == 1]
outliers_scaled = daily_nyc_taxi.loc[outliers_scaled.index]
print(outliers_scaled)

plot_outliers(outliers_scaled,daily_nyc_taxi,'KNN')
# Out:
#                    value
# timestamp
# 2014-09-27  17801.791667
# 2014-11-01  20553.500000
# 2014-11-27  10899.666667
# 2014-12-25   7902.125000
# 2014-12-26  10397.958333
# 2015-01-26   7818.979167
# 2015-01-27   4834.541667

# %%
lof = LOF(contamination=0.03, n_neighbors=5)
lof.fit(daily_nyc_taxi)

predicted_lof = pd.Series(lof.predict(daily_nyc_taxi), index=daily_nyc_taxi.index)
print('Number of outliers', predicted_knn.sum())

outliers_lof = predicted_lof[predicted_lof==1]
outliers_lof = daily_nyc_taxi.loc[outliers_lof.index]
print(outliers_lof)

plot_outliers(outliers_lof, daily_nyc_taxi, 'LOF', labels=True)
# Out:
# Number of outliers 6
#                    value
# timestamp
# 2014-10-31  17473.354167
# 2014-11-01  20553.500000
# 2014-12-25   7902.125000
# 2014-12-26  10397.958333
# 2015-01-26   7818.979167
# 2015-01-27   4834.541667

# %%
iforest = IForest(contamination=0.03,n_estimators=100,random_state=0)
iforest.fit(daily_nyc_taxi)

predicted_iforest = pd.Series(iforest.predict(daily_nyc_taxi), index=daily_nyc_taxi.index)
print('Number of outliers', predicted_iforest.sum())

outliers_iforest = predicted_iforest[predicted_iforest==1]
outliers_iforest = daily_nyc_taxi.loc[outliers_iforest.index]
print(outliers_iforest)

plot_outliers(outliers_iforest, daily_nyc_taxi, 'IForest', labels=True)
# Out:
# Number of outliers 7
#                    value
# timestamp
# 2014-11-01  20553.500000
# 2014-11-08  18857.333333
# 2014-11-27  10899.666667
# 2014-12-25   7902.125000
# 2014-12-26  10397.958333
# 2015-01-26   7818.979167
# 2015-01-27   4834.541667

# %% [markdown]
# We have identified extra outlier when compared with knn,lof in IForest on 08-11-2014

# %%
ocsvm = OCSVM(contamination=0.03, kernel='rbf')
ocsvm.fit(daily_nyc_taxi)

predicted_ocsvm = pd.Series(ocsvm.predict(daily_nyc_taxi), index=daily_nyc_taxi.index)
print('Number of outliers', predicted_ocsvm.sum())

outliers_ocsvm = predicted_ocsvm[predicted_ocsvm==1]
outliers_ocsvm = daily_nyc_taxi.loc[outliers_ocsvm.index]
print(outliers_ocsvm)

plot_outliers(outliers_ocsvm, daily_nyc_taxi, 'OCSVM', labels=True)
# Out:
# Number of outliers 5
#                    value
# timestamp
# 2014-08-09  15499.708333
# 2014-11-18  15499.437500
# 2014-11-27  10899.666667
# 2014-12-24  12502.000000
# 2015-01-05  12502.750000

# %% [markdown]
# OCSVM - rbf can able to pickup the non linear relationship data, So it pickup the robust kernel. In more general svm is sensitive to data scaling, To get better result we need to standardize data

# %%
scaled = standardizer(daily_nyc_taxi)
for kernel in ['linear', 'poly', 'rbf', 'sigmoid']:
    ocsvm = OCSVM(contamination=0.03, kernel=kernel)
    predict_ocsvm = pd.Series(ocsvm.fit_predict(scaled),
                      index=daily_nyc_taxi.index, name=kernel)
    outliers = predict_ocsvm[predict_ocsvm == 1]
    outliers = daily_nyc_taxi.loc[outliers.index]
    plot_outliers(outliers, daily_nyc_taxi, kernel, labels=True)

# %%
copod = COPOD(contamination=0.03)
copod.fit(daily_nyc_taxi)

predicted_copod = pd.Series(copod.predict(daily_nyc_taxi), index=daily_nyc_taxi.index)
print('Number of outliers', predicted_copod.sum())

outliers_copod = predicted_copod[predicted_copod==1]
outliers_copod = daily_nyc_taxi.loc[outliers_copod.index]
print(outliers_copod)

plot_outliers(outliers_copod, daily_nyc_taxi, 'COPOD', labels=True)
# Out:
# Number of outliers 7
#                    value
# timestamp
# 2014-07-04  11511.770833
# 2014-07-06  11464.270833
# 2014-11-27  10899.666667
# 2014-12-25   7902.125000
# 2014-12-26  10397.958333
# 2015-01-26   7818.979167
# 2015-01-27   4834.541667

# %% [markdown]
# COPOD and IForest identified the outliers are 7, but it identified the additional outliers other than Iforest found. July 4th and July 7th.

# %% [markdown]
# pycaret is a wrapper above the pyod

# %%
list_of_models = models().index.tolist()[0:8]
list_of_models

results = {}
for model in list_of_models:
    cols = ['value', 'Anomaly_Score']
    outlier_model = create_model(model, fraction=0.03)
    print(outlier_model)
    outliers = predict_model(outlier_model, data=daily_nyc_taxi)
    outliers = outliers[outliers['Anomaly'] == 1][cols]
    outliers.sort_values('Anomaly_Score',
ascending=False, inplace=True)
    results[model] = {'data': outliers, 'model': outlier_model}

for model in results:
    print(f'Model: {model}')
    print(results[model]['data'], '\n')
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# ABOD(contamination=0.03, method='fast', n_neighbors=5)
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# CBLOFForceToDouble(alpha=0.9, beta=5, check_estimator=False,
#           clustering_estimator=None, contamination=0.03, n_clusters=8,
#           n_jobs=None, random_state=1, use_weights=False)
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# COF(contamination=0.03, method='fast', n_neighbors=20)
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# IForest(behaviour='new', bootstrap=False, contamination=0.03,
#     max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#     random_state=1, verbose=0)
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# HBOS(alpha=0.1, contamination=0.03, n_bins=10, tol=0.5)
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# KNN(algorithm='auto', contamination=0.03, leaf_size=30, method='largest',
# ...

# %% [markdown]
# # To conclude we have calculated the anomaly score using different algorithms and spotted 7 outliers in total.

# %% [markdown]
# # Time Series Models

# %%
# Fit an AutoARIMA model
autoarima_model = auto_arima(daily_nyc_taxi['value'], seasonal=True, m=7, stepwise=True, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[7] intercept   : AIC=3682.949, Time=3.07 sec
#  ARIMA(0,0,0)(0,0,0)[7] intercept   : AIC=3867.853, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,0)[7] intercept   : AIC=3704.960, Time=2.72 sec
#  ARIMA(0,0,1)(0,0,1)[7] intercept   : AIC=3720.764, Time=0.97 sec
#  ARIMA(0,0,0)(0,0,0)[7]             : AIC=4754.343, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,1)[7] intercept   : AIC=3700.637, Time=0.88 sec
#  ARIMA(2,0,2)(1,0,0)[7] intercept   : AIC=3680.938, Time=2.31 sec
#  ARIMA(2,0,2)(0,0,0)[7] intercept   : AIC=3738.944, Time=0.25 sec
#  ARIMA(2,0,2)(2,0,0)[7] intercept   : AIC=3682.323, Time=2.00 sec
#  ARIMA(2,0,2)(2,0,1)[7] intercept   : AIC=3683.440, Time=2.50 sec
#  ARIMA(1,0,2)(1,0,0)[7] intercept   : AIC=3696.955, Time=0.92 sec
#  ARIMA(2,0,1)(1,0,0)[7] intercept   : AIC=inf, Time=2.57 sec
#  ARIMA(3,0,2)(1,0,0)[7] intercept   : AIC=3674.126, Time=2.04 sec
#  ARIMA(3,0,2)(0,0,0)[7] intercept   : AIC=3740.773, Time=0.40 sec
# ...

# %%
print(autoarima_model.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                                  y   No. Observations:                  215
# Model:             SARIMAX(3, 0, 3)x(1, 0, [], 7)   Log Likelihood               -1821.900
# Date:                            Wed, 20 Sep 2023   AIC                           3661.800
# Time:                                    19:57:23   BIC                           3692.135
# Sample:                                07-01-2014   HQIC                          3674.057
#                                      - 01-31-2015
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   8189.2840   2671.804      3.065      0.002    2952.644    1.34e+04
# ar.L1         -1.3251      0.153     -8.655      0.000      -1.625      -1.025
# ...

# %%
final_arima_model = ARIMA(daily_nyc_taxi['value'], order=(3,0,3), seasonal_order=(1,0,0,7))
final_arima_results = final_arima_model.fit()

# Print model summary
print(final_arima_results.summary())
# Out:
#                                     SARIMAX Results
# ...
# Dep. Variable:                            value   No. Observations:                  215
# Model:             ARIMA(3, 0, 3)x(1, 0, [], 7)   Log Likelihood               -1820.714
# Date:                          Wed, 20 Sep 2023   AIC                           3659.428
# Time:                                  21:19:16   BIC                           3689.764
# Sample:                              07-01-2014   HQIC                          3671.685
#                                    - 01-31-2015
# Covariance Type:                            opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.514e+04    380.408     39.788      0.000    1.44e+04    1.59e+04
# ar.L1          0.7366      0.145      5.082      0.000       0.453       1.021
# ...

# %%
# Residuals plot
residuals = final_arima_results.resid
sns.histplot(residuals, kde=True)
plt.title('Residuals Distribution')
plt.xlabel('Residuals')
plt.ylabel('Density')
plt.show()

# ACF and PACF of residuals
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
plot_acf(residuals, ax=ax1, lags=40)
plot_pacf(residuals, ax=ax2, lags=40)
plt.show()

# %%
# Forecast Value
forecast_periods = 7  # Change as needed
forecast_values = final_arima_results.forecast(steps=forecast_periods)

# Get the last date in your observed data
last_observed_date = daily_nyc_taxi.index[-1]

# Create a date range that aligns with the forecast periods and matches the frequency of your data
forecast_index = pd.date_range(start=last_observed_date + pd.DateOffset(days=1), periods=forecast_periods, freq=daily_nyc_taxi.index.freq)

# Plot the forecasts
plt.figure(figsize=(12, 6))
plt.plot(daily_nyc_taxi.index, daily_nyc_taxi['value'], label='Observed')
plt.plot(forecast_index, forecast_values, label='Forecast', color='red')
plt.title('ARIMA Forecast')
plt.xlabel('Date')
plt.ylabel('Demand')
plt.legend()
plt.show()

# %%
# Adapting prohpet by changing the coloumns
daily_nyc_taxi.reset_index(inplace=True)
daily_nyc_taxi.rename(columns={'timestamp': 'ds', 'value': 'y'}, inplace=True)

# Create a Prophet model
model = Prophet()

# Fit the model to your data
model.fit(daily_nyc_taxi)

# Create a DataFrame with future dates for forecasting
future = model.make_future_dataframe(periods=7)

# Make forecasts
forecast = model.predict(future)

# Plot the forecasts
fig = model.plot(forecast)
plt.title('Prophet Forecast')
plt.xlabel('Date')
plt.ylabel('Demand')
plt.show()
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1f85y561/1t7di83q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1f85y561/o0ascig8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16812', 'data', 'file=/tmp/tmp1f85y561/1t7di83q.json', 'init=/tmp/tmp1f85y561/o0ascig8.json', 'output', 'file=/tmp/tmp1f85y561/prophet_modelsjwly1m_/prophet_model-20230920213406.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:34:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:34:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Plot the forecast components (trend)
fig = model.plot_components(forecast)
plt.show()

# %%
# Extend the future DataFrame with more periods (7 additional days)
future_extended = model.make_future_dataframe(periods=7)

# Make forecasts for the extended future
forecast_extended = model.predict(future_extended)

# Access the forecasted values for the extended period
forecast_values_extended = forecast_extended['yhat'][-7:]

# Extract the relevant columns from the forecast_extended DataFrame
forecast_values_original = forecast_extended['yhat'][:len(daily_nyc_taxi)]  # Forecast values for the original period

# Plot the forecasts
plt.figure(figsize=(12, 6))
plt.plot(daily_nyc_taxi['ds'], daily_nyc_taxi['y'], label='Observed (Original)')
plt.plot(future_extended['ds'][-7:], forecast_values_extended, label='Forecast (Extended)', color='red')
plt.title('Prophet Forecast (Extended)')
plt.xlabel('Date')
plt.ylabel('Demand')
plt.legend()
plt.show()

# %%
# Extend the future DataFrame with more periods (e.g., 7 additional days)
future_extended = model.make_future_dataframe(periods=7)

# Make forecasts for the extended future
forecast_extended = model.predict(future_extended)

# Plot the forecasts
plt.figure(figsize=(12, 6))
plt.plot(daily_nyc_taxi['ds'], daily_nyc_taxi['y'], label='Observed (Original)')
plt.plot(forecast_extended['ds'], forecast_extended['yhat'], label='Forecast', color='red')
plt.fill_between(forecast_extended['ds'], forecast_extended['yhat_lower'], forecast_extended['yhat_upper'], color='pink', alpha=0.3)
plt.title('Prophet Forecast (Extended)')
plt.xlabel('Date')
plt.ylabel('Demand')
plt.legend()
plt.show()
